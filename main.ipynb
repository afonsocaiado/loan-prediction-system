# %%
import pandas as pd

account_data = pd.read_csv('data/account.csv', na_values=['NA'], sep=';')
client_data = pd.read_csv('data/client.csv', na_values=['NA'], sep=';')
disp_data = pd.read_csv('data/disp.csv', na_values=['NA'], sep=';')
district_data = pd.read_csv('data/district.csv', na_values=['NA'], sep=';')
loan_train_data = pd.read_csv('data/loan_train.csv', na_values=['NA'], sep=';')
loan_test_data = pd.read_csv('data/loan_test.csv', na_values=['NA'], sep=';')
#trans_train_data = pd.read_csv('data/trans_train.csv', na_values=['NA'], sep=';')
trans_test_data = pd.read_csv('data/trans_test.csv', na_values=['NA'], sep=';')
card_train_data = pd.read_csv('data/card_train.csv', na_values=['NA'], sep=';')
card_test_data = pd.read_csv('data/card_test.csv', na_values=['NA'], sep=';')

loan_train_data.describe()
# Out:
#            loan_id    account_id           date         amount    duration  \
# count   328.000000    328.000000     328.000000     328.000000  328.000000
# mean   6205.658537   5982.085366  949989.125000  145308.621951   35.853659
# std     667.985675   3213.262492    9495.504646  105247.318098   16.734752
# min    4959.000000      2.000000  930705.000000    4980.000000   12.000000
# 25%    5604.250000   3079.000000  940809.250000   68328.000000   24.000000
# 50%    6227.500000   6032.000000  950565.500000  114804.000000   36.000000
# 75%    6737.250000   8564.500000  960525.250000  198600.000000   48.000000
# max    7308.000000  11362.000000  961227.000000  538500.000000   60.000000
#
#           payments      status
# count   328.000000  328.000000
# mean   4150.932927    0.719512
# std    2193.620989    0.695541
# min     319.000000   -1.000000
# 25%    2368.750000    1.000000
# 50%    3878.500000    1.000000
# 75%    5907.750000    1.000000
# max    9689.000000    1.000000

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sb

sb.pairplot(loan_train_data.dropna(), hue='status');
# Out:
# ''

# %%
loan_test_data.hist();

# %%
df = pd.DataFrame([i['status'] for i in loan_train_data i['status'] != 1], columns = ['one'])
df['two'] = [i['amount'] for i in loan_train_data if i['status'] != 1]
df.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-641f8ffbe3ab> in <module>
# ----> 1 df = pd.DataFrame([i['status'] for i in loan_train_data], columns = ['one'])
#       2 df['two'] = [i['amount'] for i in loan_train_data if i['status'] != 1]
#       3 df.plot.hist()
#
# <ipython-input-41-641f8ffbe3ab> in <listcomp>(.0)
# ----> 1 df = pd.DataFrame([i['status'] for i in loan_train_data], columns = ['one'])
#       2 df['two'] = [i['amount'] for i in loan_train_data if i['status'] != 1]
#       3 df.plot.hist()
#
# TypeError: string indices must be integers
